# %%
import os
from pathlib import Path
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer

# %%
dataframe = pd.read_excel('Air_Quality_Regression/data/AirQualityUCI.xlsx')
dataframe.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   datetime64[ns]
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
num_cols = dataframe.select_dtypes(include='number').columns.to_list()
num_dataframe = dataframe[num_cols]
num_values_dict = {}
for num_col in num_cols:
  num_values_dict[num_col] = (dataframe[num_col] == -200).sum()

null_num_values = pd.DataFrame.from_dict(num_values_dict, orient='index', columns=['null_values'])
null_num_values
# Out:
#                null_values
# CO(GT)                1683
# PT08.S1(CO)            366
# NMHC(GT)              8443
# C6H6(GT)               366
# PT08.S2(NMHC)          366
# NOx(GT)               1639
# PT08.S3(NOx)           366
# NO2(GT)               1642
# PT08.S4(NO2)           366
# PT08.S5(O3)            366
# T                      366
# RH                     366
# AH                     366

# %%
mean_imputer = SimpleImputer(missing_values=-200, strategy='mean')
median_imputer = SimpleImputer(missing_values=-200, strategy='median')
mean_imputer.fit(dataframe[num_cols])
median_imputer.fit(dataframe[num_cols])
# Out:
# SimpleImputer(missing_values=-200, strategy='median')

# %%
dataframe[num_cols].describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %%
mean_filled_dataframe = pd.DataFrame(mean_imputer.transform(dataframe[num_cols]), columns=num_cols)
median_filled_dataframe = pd.DataFrame(median_imputer.transform(dataframe[num_cols]), columns=num_cols)

# %%
mean_filled_dataframe.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean      2.152750  1099.707856   218.811816    10.082993     939.029205
# std       1.316068   212.796116    63.870229     7.302474     261.557856
# min       0.100000   647.250000     7.000000     0.149048     383.250000
# 25%       1.200000   941.250000   218.811816     4.591495     742.500000
# 50%       2.152750  1074.500000   218.811816     8.593367     923.250000
# 75%       2.600000  1221.250000   218.811816    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    246.881252    835.370973   113.075515   1456.143486  1022.780725
# std     193.419417    251.741784    43.911095    339.365351   390.609000
# ...

# %%
median_filled_dataframe.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean      2.089302  1098.272025   156.721599    10.010899     937.854610
# std       1.323024   212.915093    67.058156     7.311212     261.622644
# min       0.100000   647.250000     7.000000     0.149048     383.250000
# 25%       1.200000   941.250000   150.000000     4.591495     742.500000
# 50%       1.800000  1063.000000   150.000000     8.239851     909.000000
# 75%       2.600000  1221.250000   150.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    235.131100    834.202567   112.360329   1456.401901  1020.452175
# std     195.093027    251.808390    43.938455    339.367768   390.779481
# ...

# %%
cat_cols = dataframe.select_dtypes(exclude='number').columns.to_list()
full_dataframe = pd.concat([dataframe[cat_cols], mean_filled_dataframe], axis=1)

# %%
full_dataframe.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00     150.0  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25     112.0   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00      88.0   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50      80.0   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25      51.0   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# ...

# %%
fig = plt.figure(figsize=(15,10))
num_cols.remove('T')
for i, col in enumerate(num_cols):
  fig.add_subplot(4, 4, i + 1)
  plt.scatter(full_dataframe[col], full_dataframe['T'], s=1)
  plt.xlabel(col)
  plt.ylabel('T')
  plt.title(f'{col} vs T')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
num_cols.append('T')
correlation_matrix = full_dataframe[num_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.tight_layout()
plt.show()
